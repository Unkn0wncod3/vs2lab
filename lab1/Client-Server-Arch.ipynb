# %% [markdown]
# # Running server and client in a single notebook
# Note: not working with Windows
# ## Server part

# %%
import clientserver # import from our script
import os # os module needed for spawning another process

server = clientserver.Server() # Create a server instance
    
pid = os.fork() # we need to fork here in order not to block the notebook
print(pid)
if pid == 0: # run server in forked process
    server.serve() # start server routine in the forked process
    os._exit(0) # after finisching the server routine, kill the forked process
# Out:
# 2026-04-09 12:22:54,128 - vs2lab.lab1.clientserver.Server - INFO - Server bound to socket <socket.socket fd=82, family=2, type=1, proto=0, laddr=('127.0.0.1', 50007)>
# 1179
# 0
# /tmp/ipykernel_890/2618695545.py:6: DeprecationWarning: This process (pid=890) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork() # we need to fork here in order not to block the notebook
# 2026-04-09 12:22:54,227 - vs2lab.lab1.clientserver.Server - INFO - Server listening on 127.0.0.1:50007
# 2026-04-09 12:23:04,008 - vs2lab.lab1.clientserver.Server - INFO - Accepted connection from ('127.0.0.1', 40708)
# 2026-04-09 12:23:04,015 - vs2lab.lab1.clientserver.Server - INFO - Received request {'command': 'GET', 'name': 'Alice'}
# 2026-04-09 12:23:04,018 - vs2lab.lab1.clientserver.Server - INFO - Sending response {'status': 'OK', 'name': 'Alice', 'number': '040-123456'}
# 2026-04-09 12:23:04,022 - vs2lab.lab1.clientserver.Server - INFO - Closed connection to ('127.0.0.1', 40708)
# 2026-04-09 12:24:04,085 - vs2lab.lab1.clientserver.Server - INFO - Accepted connection from ('127.0.0.1', 36818)
# 2026-04-09 12:24:04,091 - vs2lab.lab1.clientserver.Server - INFO - Received request {'command': 'GET', 'name': 'Alice'}
# 2026-04-09 12:24:04,096 - vs2lab.lab1.clientserver.Server - INFO - Sending response {'status': 'OK', 'name': 'Alice', 'number': '040-123456'}
# 2026-04-09 12:24:04,100 - vs2lab.lab1.clientserver.Server - INFO - Closed connection to ('127.0.0.1', 36818)
# 2026-04-09 12:24:04,124 - vs2lab.lab1.clientserver.Server - INFO - Accepted connection from ('127.0.0.1', 36828)
# 2026-04-09 12:24:04,130 - vs2lab.lab1.clientserver.Server - INFO - Received request {'command': 'GET', 'name': 'Mallory'}
# 2026-04-09 12:24:04,137 - vs2lab.lab1.clientserver.Server - INFO - Sending response {'status': 'NOTFOUND', 'name': 'Mallory'}
# 2026-04-09 12:24:04,141 - vs2lab.lab1.clientserver.Server - INFO - Closed connection to ('127.0.0.1', 36828)
# 2026-04-09 12:24:04,147 - vs2lab.lab1.clientserver.Server - INFO - Accepted connection from ('127.0.0.1', 36836)
# 2026-04-09 12:24:04,154 - vs2lab.lab1.clientserver.Server - INFO - Received request {'command': 'GETALL'}
# 2026-04-09 12:24:04,158 - vs2lab.lab1.clientserver.Server - INFO - Sending response {'status': 'OK', 'entry_count': 3}
# 2026-04-09 12:24:04,161 - vs2lab.lab1.clientserver.Server - INFO - Closed connection to ('127.0.0.1', 36836)
# 2026-04-09 12:26:05,514 - vs2lab.lab1.clientserver.Server - INFO - Accepted connection from ('127.0.0.1', 36700)
# 2026-04-09 12:26:05,523 - vs2lab.lab1.clientserver.Server - INFO - Received request {'command': 'GET', 'name': 'Alice'}
# 2026-04-09 12:26:05,530 - vs2lab.lab1.clientserver.Server - INFO - Sending response {'status': 'OK', 'name': 'Alice', 'number': '040-123456'}
# 2026-04-09 12:26:05,534 - vs2lab.lab1.clientserver.Server - INFO - Closed connection to ('127.0.0.1', 36700)
# 2026-04-09 12:26:05,540 - vs2lab.lab1.clientserver.Server - INFO - Accepted connection from ('127.0.0.1', 36708)
# 2026-04-09 12:26:05,547 - vs2lab.lab1.clientserver.Server - INFO - Received request {'command': 'GET', 'name': 'Mallory'}
# 2026-04-09 12:26:05,550 - vs2lab.lab1.clientserver.Server - INFO - Sending response {'status': 'NOTFOUND', 'name': 'Mallory'}
# 2026-04-09 12:26:05,554 - vs2lab.lab1.clientserver.Server - INFO - Closed connection to ('127.0.0.1', 36708)
# 2026-04-09 12:26:05,561 - vs2lab.lab1.clientserver.Server - INFO - Accepted connection from ('127.0.0.1', 36724)
# 2026-04-09 12:26:05,572 - vs2lab.lab1.clientserver.Server - INFO - Received request {'command': 'GETALL'}
# 2026-04-09 12:26:05,576 - vs2lab.lab1.clientserver.Server - INFO - Sending response {'status': 'OK', 'entry_count': 3}
# 2026-04-09 12:26:05,579 - vs2lab.lab1.clientserver.Server - INFO - Closed connection to ('127.0.0.1', 36724)
# 2026-04-09 12:26:33,995 - vs2lab.lab1.clientserver.Server - INFO - Accepted connection from ('127.0.0.1', 55602)
# 2026-04-09 12:26:34,006 - vs2lab.lab1.clientserver.Server - INFO - Received request {'command': 'GET', 'name': 'Alice'}
# 2026-04-09 12:26:34,010 - vs2lab.lab1.clientserver.Server - INFO - Sending response {'status': 'OK', 'name': 'Alice', 'number': '040-123456'}
# 2026-04-09 12:26:34,016 - vs2lab.lab1.clientserver.Server - INFO - Closed connection to ('127.0.0.1', 55602)
# 2026-04-09 12:26:34,023 - vs2lab.lab1.clientserver.Server - INFO - Accepted connection from ('127.0.0.1', 55610)
# 2026-04-09 12:26:34,026 - vs2lab.lab1.clientserver.Server - INFO - Received request {'command': 'GET', 'name': 'Mallory'}
# 2026-04-09 12:26:34,029 - vs2lab.lab1.clientserver.Server - INFO - Sending response {'status': 'NOTFOUND', 'name': 'Mallory'}
# 2026-04-09 12:26:34,032 - vs2lab.lab1.clientserver.Server - INFO - Closed connection to ('127.0.0.1', 55610)
# 2026-04-09 12:26:34,038 - vs2lab.lab1.clientserver.Server - INFO - Accepted connection from ('127.0.0.1', 55620)
# 2026-04-09 12:26:34,042 - vs2lab.lab1.clientserver.Server - INFO - Received request {'command': 'GETALL'}
# 2026-04-09 12:26:34,045 - vs2lab.lab1.clientserver.Server - INFO - Sending response {'status': 'OK', 'entry_count': 3}
# 2026-04-09 12:26:34,050 - vs2lab.lab1.clientserver.Server - INFO - Closed connection to ('127.0.0.1', 55620)
# 2026-04-09 12:26:43,201 - vs2lab.lab1.clientserver.Server - INFO - Accepted connection from ('127.0.0.1', 38876)
# 2026-04-09 12:26:43,206 - vs2lab.lab1.clientserver.Server - INFO - Received request {'command': 'GET', 'name': 'Alice'}
# 2026-04-09 12:26:43,209 - vs2lab.lab1.clientserver.Server - INFO - Sending response {'status': 'OK', 'name': 'Alice', 'number': '040-123456'}
# 2026-04-09 12:26:43,212 - vs2lab.lab1.clientserver.Server - INFO - Closed connection to ('127.0.0.1', 38876)
# 2026-04-09 12:26:43,219 - vs2lab.lab1.clientserver.Server - INFO - Accepted connection from ('127.0.0.1', 38890)
# 2026-04-09 12:26:43,222 - vs2lab.lab1.clientserver.Server - INFO - Received request {'command': 'GET', 'name': 'Mallory'}
# 2026-04-09 12:26:43,225 - vs2lab.lab1.clientserver.Server - INFO - Sending response {'status': 'NOTFOUND', 'name': 'Mallory'}
# 2026-04-09 12:26:43,228 - vs2lab.lab1.clientserver.Server - INFO - Closed connection to ('127.0.0.1', 38890)
# 2026-04-09 12:26:43,235 - vs2lab.lab1.clientserver.Server - INFO - Accepted connection from ('127.0.0.1', 38902)
# 2026-04-09 12:26:43,239 - vs2lab.lab1.clientserver.Server - INFO - Received request {'command': 'GETALL'}
# 2026-04-09 12:26:43,241 - vs2lab.lab1.clientserver.Server - INFO - Sending response {'status': 'OK', 'entry_count': 3}
# 2026-04-09 12:26:43,244 - vs2lab.lab1.clientserver.Server - INFO - Closed connection to ('127.0.0.1', 38902)

# %% [markdown]
# ## Client
# Now create a client object and call the server

# %%
import clientserver # import from our script

client = clientserver.Client() # Create a client instance

client.call() # start the call and print echo
# Out:
# 2026-04-09 12:23:04,004 - vs2lab.lab1.clientserver.Client - INFO - Connecting to 127.0.0.1:50007
# 2026-04-09 12:23:04,009 - vs2lab.lab1.clientserver.Client - INFO - Client connected to socket <socket.socket fd=83, family=2, type=1, proto=0, laddr=('127.0.0.1', 40708), raddr=('127.0.0.1', 50007)>
# 2026-04-09 12:23:04,012 - vs2lab.lab1.clientserver.Client - INFO - Sent request {'command': 'GET', 'name': 'Alice'}
# 2026-04-09 12:23:04,022 - vs2lab.lab1.clientserver.Client - INFO - Received response {'status': 'OK', 'name': 'Alice', 'number': '040-123456'}
# 2026-04-09 12:23:04,024 - vs2lab.lab1.clientserver.Client - INFO - Client down.
# 040-123456
# '040-123456'

# %% [markdown]
# That was all. The server process has terminated as well after returning the echo message.
