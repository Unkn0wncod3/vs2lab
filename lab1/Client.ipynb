# %% [markdown]
# # Telefonauskunft: Client

# %%
import clientserver

client = clientserver.Client()

print("Person001:", client.get("Person001"))
print("Person999:", client.get("Person999"))
print("Alle Einträge:", client.getall())
# Out:
# 2026-04-09 13:21:36,490 - vs2lab.lab1.clientserver.Client - INFO - Connecting to 127.0.0.1:50007
# 2026-04-09 13:21:36,512 - vs2lab.lab1.clientserver.Client - INFO - Client connected to socket <socket.socket fd=81, family=2, type=1, proto=0, laddr=('127.0.0.1', 52892), raddr=('127.0.0.1', 50007)>
# 2026-04-09 13:21:36,519 - vs2lab.lab1.clientserver.Client - INFO - Sent request {'command': 'GET', 'name': 'Person001'}
# 2026-04-09 13:21:36,523 - vs2lab.lab1.clientserver.Client - INFO - Received response {'status': 'OK', 'name': 'Person001', 'number': '042-770487'}
# 2026-04-09 13:21:36,528 - vs2lab.lab1.clientserver.Client - INFO - Client down.
# 2026-04-09 13:21:36,533 - vs2lab.lab1.clientserver.Client - INFO - Connecting to 127.0.0.1:50007
# 2026-04-09 13:21:36,536 - vs2lab.lab1.clientserver.Client - INFO - Client connected to socket <socket.socket fd=80, family=2, type=1, proto=0, laddr=('127.0.0.1', 52904), raddr=('127.0.0.1', 50007)>
# ...
